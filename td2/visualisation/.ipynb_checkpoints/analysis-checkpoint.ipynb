# %% [markdown]
# # Load libraries

# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Parse csv and Load data

# %%
structures = ['array', 'hashmap', 'queue', 'stack', 'treeset']
type_str = ['immutable', 'mutable']

# %%
import glob

path = 'data'

files = [f[5:-4].split('-') for f in glob.glob(path + "/*.csv")]
data = pd.DataFrame(files,columns=['type', 'struc', 'action'])
data['path'] = 'data/'+ data.loc[:,'type'] + '-'+ data_info.loc[:,'struc'] + '-' + + data.loc[:,'action']+'.csv'
data['data'] = data['path'].apply(lambda x: pd.read_csv(x))
data.head()
# Out:
#         type    struc   action                            path  \
# 0    mutable     heap   remove    data/mutable-heap-remove.csv
# 1  immutable  treeset      add  data/immutable-treeset-add.csv
# 2  immutable  hashmap      get  data/immutable-hashmap-get.csv
# 3    mutable    array      set      data/mutable-array-set.csv
# 4    mutable    queue  dequeue  data/mutable-queue-dequeue.csv
#
#                                                 data
# 0      size     start_time      stop_time  total_...
# 1      size     start_time      stop_time  total_...
# 2      size     start_time      stop_time  total_...
# 3      size     start_time      stop_time  total_...
# 4      size     start_time      stop_time  total_...

# %% [markdown]
# ###  Creating the log_run_time

# %%
'''
This function computes the log base 2 of the parameter passed to the function
If the parameter is equal to zero then we assume it's equal to 1 because it isn't that big of a difference in milliseconds
'''
def log_time(run_time):
    if run_time ==0:
        run_time=1
    return math.log(run_time,2)

# %%
 for row in data.itertuples():
        row.data['log_run_time'] = row.data.loc[:,"total_time"].apply(lambda x: log_time(x))

# %%
data.loc[:,'data'].iloc[0]
# Out:
#     size     start_time      stop_time  total_time  log_run_time
# 0      1  1571122230394  1571122230395           1      0.000000
# 1      2  1571122230395  1571122230395           0      0.000000
# 2      3  1571122230395  1571122230395           0      0.000000
# 3      4  1571122230395  1571122230395           0      0.000000
# 4      5  1571122230396  1571122230396           0      0.000000
# 5      6  1571122230396  1571122230396           0      0.000000
# 6      7  1571122230396  1571122230396           0      0.000000
# 7      8  1571122230397  1571122230397           0      0.000000
# 8      9  1571122230397  1571122230398           1      0.000000
# 9     10  1571122230398  1571122230398           0      0.000000
# 10    11  1571122230398  1571122230399           1      0.000000
# 11    12  1571122230399  1571122230400           1      0.000000
# 12    13  1571122230400  1571122230402           2      1.000000
# 13    14  1571122230403  1571122230404           1      0.000000
# 14    15  1571122230404  1571122230407           3      1.584963
# 15    16  1571122230408  1571122230413           5      2.321928
# 16    17  1571122230414  1571122230424          10      3.321928
# 17    18  1571122230425  1571122230447          22      4.459432
# 18    19  1571122230450  1571122230493          43      5.426265
# 19    20  1571122230499  1571122230588          89      6.475733
# 20    21  1571122230600  1571122230785         185      7.531381
# 21    22  1571122230810  1571122231168         358      8.483816
# 22    23  1571122231217  1571122231926         709      9.469642
# 23    24  1571122232021  1571122233478        1457     10.508785

# %% [markdown]
# ## Plot by structure

# %%
struc = np.unique(data.loc[:,'struc'])
type_str = np.unique(data.loc[:,'type'])
print(struc)
# Out:
# ['array' 'hashmap' 'heap' 'queue' 'stack' 'treeset']

# %%
for x in struc:
    df = data[data.loc[:,'struc'] == x]
    
    fig = plt.figure(figsize=(6, 6))
    plt.title(x)
    
    for row in df.itertuples():
        _type = row.type
        _action = row.action
        bench_data = row.data
        bench_data['log_run_time'] 
        plt.plot(bench_data.loc[:,"size"], bench_data.loc[:,"log_run_time"], label=(_type+_action))

    plt.legend()
    plt.show()

# %% [markdown]
# ### Limiting the x axis

# %%
for x in struc:
    df = data[data.loc[:,'struc'] == x]
    
    fig = plt.figure(figsize=(6, 6))
    plt.title(x)
    
    for row in df.itertuples():
        _type = row.type
        _action = row.action
        bench_data = row.data.iloc[15:]

        plt.plot(bench_data.loc[:,"size"], bench_data.loc[:,"log_run_time"], label=(_type+_action))

    plt.legend()
    plt.show()

# %% [markdown]
# ## Computing the coefficients for each structure

# %%
for x in struc:
    df = data[data.loc[:,'struc'] == x]
    
    fig = plt.figure(figsize=(6, 6))
    plt.title(x)
    axes = plt.gca()
    axes.set_xlim([0,25])
    #axes.set_ylim([-10,10])
    
    for row in df.itertuples():
        _type = row.type
        _action = row.action
        bench_data = row.data

        cov = bench_data.loc[:,['log_run_time','size']].cov().iloc[0][1]

        a = cov/bench_data["size"].var()
        b = bench_data["log_run_time"].mean() - bench_data["size"].mean()*a
        print((_type+' '+_action))
        print("a: " + str(a) + ", b: " + str(b),'\n')

        x = np.arange(0,25)
        y = x*a + b
        
        plt.plot(x, y, label=(_type+' '+_action+' '+'model'))

    plt.legend()
    plt.show()
# Out:
# mutable set
# a: 0.4550734118171681, b: -2.9078722172302345
#
# immutable set
# a: 0.9214123266787602, b: -4.477809235879422
#
# mutable get
# a: 0.20726223192862336, b: -1.5265088825934268
#
# immutable get
# a: 0.017543859649122806, b: -0.1111111111111111
# immutable get
# a: 0.5631530821659236, b: -3.61876318141385
#
# mutable remove
# a: 0.49737168222462197, b: -3.4563764723473445
#
# immutable put
# a: 0.6131782905302907, b: -3.6573240949428465
#
# mutable get
# a: 0.5115727487246601, b: -3.4959662477641236
#
# mutable put
# a: 0.5617565928197439, b: -3.2954313424869017
#
# immutable remove
# a: 0.6287914862801838, b: -3.634761742043569
# mutable remove
# a: 0.4354771193864125, b: -2.919135962668228
#
# mutable insert
# a: 0.20449175165527186, b: -1.5460698878345185
# mutable dequeue
# a: 0.3411706727135654, b: -2.4753557133162474
#
# mutable enqueue
# a: 0.5069024273202966, b: -3.4185774899941337
#
# immutable dequeue
# a: 0.423146951596444, b: -3.0881370169456015
#
# immutable enqueue
# a: 0.423146951596444, b: -3.0881370169456015
# mutable pop
# a: 0.28946268650371865, b: -2.1135246472783003
#
# immutable pop
# a: 0.2666890162402023, b: -1.9688178990443885
#
# immutable push
# a: 0.4847378233128656, b: -3.440063490158291
#
# mutable push
# a: 0.4918842499129167, b: -3.4676018671618016
# immutable add
# a: 0.5338745922603938, b: -3.0372860400055806
#
# immutable remove
# a: 0.5543204330244828, b: -3.323079359827249
#
# immutable contains
# a: 0.45690945682034845, b: -2.984746696564405

# %% [markdown]
# ### Superposition of benchmarks and regression

# %%
for x in struc:
    df = data[data.loc[:,'struc'] == x]
    
    fig = plt.figure(figsize=(6, 6))
    plt.title(x)
    axes = plt.gca()
    axes.set_xlim([0,25])
    #axes.set_ylim([-10,10])
    
    for row in df.itertuples():
        _type = row.type
        _action = row.action
        bench_data = row.data

        cov = bench_data.loc[:,['log_run_time','size']].cov().iloc[0][1]

        a = cov/bench_data["size"].var()
        b = bench_data["log_run_time"].mean() - bench_data["size"].mean()*a
        print((_type+' '+ _action))
        print("a: " + str(a) + ", b: " + str(b),'\n')

        x = np.arange(0,25)
        y = x*a + b
        
        plt.plot(bench_data.loc[:,"size"], bench_data.loc[:,"log_run_time"], label=(_type+_action))
        plt.plot(x, y, label=(_type+_action))
        

    plt.legend()
    plt.show()
# Out:
# mutable set
# a: 0.4550734118171681, b: -2.9078722172302345
#
# immutable set
# a: 0.9214123266787602, b: -4.477809235879422
#
# mutable get
# a: 0.20726223192862336, b: -1.5265088825934268
#
# immutable get
# a: 0.017543859649122806, b: -0.1111111111111111
# immutable get
# a: 0.5631530821659236, b: -3.61876318141385
#
# mutable remove
# a: 0.49737168222462197, b: -3.4563764723473445
#
# immutable put
# a: 0.6131782905302907, b: -3.6573240949428465
#
# mutable get
# a: 0.5115727487246601, b: -3.4959662477641236
#
# mutable put
# a: 0.5617565928197439, b: -3.2954313424869017
#
# immutable remove
# a: 0.6287914862801838, b: -3.634761742043569
# mutable remove
# a: 0.4354771193864125, b: -2.919135962668228
#
# mutable insert
# a: 0.20449175165527186, b: -1.5460698878345185
# mutable dequeue
# a: 0.3411706727135654, b: -2.4753557133162474
#
# mutable enqueue
# a: 0.5069024273202966, b: -3.4185774899941337
#
# immutable dequeue
# a: 0.423146951596444, b: -3.0881370169456015
#
# immutable enqueue
# a: 0.423146951596444, b: -3.0881370169456015
# mutable pop
# a: 0.28946268650371865, b: -2.1135246472783003
#
# immutable pop
# a: 0.2666890162402023, b: -1.9688178990443885
#
# immutable push
# a: 0.4847378233128656, b: -3.440063490158291
#
# mutable push
# a: 0.4918842499129167, b: -3.4676018671618016
# immutable add
# a: 0.5338745922603938, b: -3.0372860400055806
#
# immutable remove
# a: 0.5543204330244828, b: -3.323079359827249
#
# immutable contains
# a: 0.45690945682034845, b: -2.984746696564405
