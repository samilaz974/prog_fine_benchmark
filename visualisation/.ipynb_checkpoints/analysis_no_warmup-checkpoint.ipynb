# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# TODO: Add quicksort when fixed
sort_algos = ["SelectionSort", "InsertionSort", "MergeSort", "CountingSort", "NativeSort", "HeapSort", "QuickSort"]

# %% [markdown]
# # Load data

# %%
data={}
for x in sort_algos:
        data[x]=pd.read_csv("./data/" + x + ".csv")

# %% [markdown]
# ### Run this cell to visualize all the raw data

# %%
for algo, df in data.items():
    print(algo)
    print(df.head(),"\n")
# Out:
# SelectionSort
#    power     start_time      stop_time
# 0      1  1569916016226  1569916016230
# 1      2  1569916016230  1569916016231
# 2      3  1569916016231  1569916016232
# 3      4  1569916016232  1569916016235
# 4      5  1569916016235  1569916016240
#
# InsertionSort
#    power     start_time      stop_time
# 0      1  1569915893138  1569915893142
# 1      2  1569915893144  1569915893144
# 2      3  1569915893145  1569915893145
# 3      4  1569915893146  1569915893147
# 4      5  1569915893147  1569915893148
#
# MergeSort
#    power     start_time      stop_time
# 0      1  1569915997312  1569915997317
# 1      2  1569915997317  1569915997319
# 2      3  1569915997319  1569915997322
# 3      4  1569915997322  1569915997325
# 4      5  1569915997326  1569915997331
#
# CountingSort
#    power     start_time      stop_time
# 0      1  1569916000988  1569916001006
# 1      2  1569916001007  1569916001011
# 2      3  1569916001011  1569916001016
# 3      4  1569916001017  1569916001022
# 4      5  1569916001022  1569916001028
#
# NativeSort
#    power     start_time      stop_time
# 0      1  1569916002689  1569916002693
# 1      2  1569916002694  1569916002695
# 2      3  1569916002695  1569916002696
# 3      4  1569916002696  1569916002698
# 4      5  1569916002699  1569916002704
#
# HeapSort
#    power     start_time      stop_time
# 0      1  1569916011029  1569916011033
# 1      2  1569916011033  1569916011034
# 2      3  1569916011034  1569916011034
# 3      4  1569916011035  1569916011036
# 4      5  1569916011036  1569916011038
#
# QuickSort
#    power     start_time      stop_time
# 0      1  1569915992862  1569915992866
# 1      2  1569915992866  1569915992867
# 2      3  1569915992868  1569915992868
# 3      4  1569915992869  1569915992871
# 4      5  1569915992871  1569915992875

# %% [markdown]
# ### Run the next 2 cells to see first dataframe and quick metrics about it

# %%
data[sort_algos[0]].head()
# Out:
#    power     start_time      stop_time
# 0      1  1569916016226  1569916016230
# 1      2  1569916016230  1569916016231
# 2      3  1569916016231  1569916016232
# 3      4  1569916016232  1569916016235
# 4      5  1569916016235  1569916016240

# %%
data[sort_algos[0]].describe()
# Out:
#          power    start_time     stop_time
# count  14.0000  1.400000e+01  1.400000e+01
# mean    7.5000  1.569916e+12  1.569916e+12
# std     4.1833  6.111996e+04  2.443425e+05
# min     1.0000  1.569916e+12  1.569916e+12
# 25%     4.2500  1.569916e+12  1.569916e+12
# 50%     7.5000  1.569916e+12  1.569916e+12
# 75%    10.7500  1.569916e+12  1.569916e+12
# max    14.0000  1.569916e+12  1.569917e+12

# %% [markdown]
# # Creating the new features
#
# - running time in miliseconds<br>
# ...

# %%
for algo, df in data.items():
    df["run_time"] = df.loc[:,"stop_time"] - df.loc[:,"start_time"]

# %%
data[sort_algos[0]].head()
# Out:
#    power     start_time      stop_time  run_time
# 0      1  1569916016226  1569916016230         4
# 1      2  1569916016230  1569916016231         1
# 2      3  1569916016231  1569916016232         1
# 3      4  1569916016232  1569916016235         3
# 4      5  1569916016235  1569916016240         5

# %% [markdown]
# # Plotting runtime for each sort

# %%
# INDIVIDUAL PLOT
for algo, df in data.items():
    # simply plotting without the log add param `logx = True` or `logy = True` for log on x or y axis to the plot function
    # check pandas dataframe.plot() for more details
    df.plot(x='power', y='run_time', title=algo)
plt.show()

# %%
# GROUPED PLOT
fig = plt.figure()

for algo, df in data.items():
    plt.plot(df.loc[:,"power"], df.loc[:,"run_time"], label=algo)

plt.legend()
plt.show()

# %%
# GROUPED PLOT
fig = plt.figure()

for algo, df in data.items():
    if algo is not "SelectionSort":
        plt.plot(df.loc[:,"power"], df.loc[:,"run_time"], label=algo)

plt.legend()
plt.show()

# %%
# GROUPED PLOT
fig = plt.figure()

for algo, df in data.items():
    if algo not in ["SelectionSort", "InsertionSort"]:
        plt.plot(df.loc[:,"power"], df.loc[:,"run_time"], label=algo)

plt.legend()
plt.show()

# %% [markdown]
# # Computing the coeff

# %%
for algo, df in data.items():
    df["elements"] = df.loc[:,"power"].apply(lambda x: np.power(2,x))

# %%
data[sort_algos[0]]
# Out:
#     power     start_time      stop_time  run_time  elements
# 0       1  1569916016226  1569916016230         4         2
# 1       2  1569916016230  1569916016231         1         4
# 2       3  1569916016231  1569916016232         1         8
# 3       4  1569916016232  1569916016235         3        16
# 4       5  1569916016235  1569916016240         5        32
# 5       6  1569916016241  1569916016247         6        64
# 6       7  1569916016248  1569916016269        21       128
# 7       8  1569916016271  1569916016420       149       256
# 8       9  1569916016425  1569916017061       636       512
# 9      10  1569916017070  1569916019668      2598      1024
# 10     11  1569916019686  1569916029941     10255      2048
# 11     12  1569916029977  1569916071461     41484      4096
# 12     13  1569916071534  1569916243634    172100      8192
# 13     14  1569916243787  1569916924899    681112     16384

# %%
for algo, df in data.items():
    print(algo)
    cov = df.loc[:,['run_time','elements']].cov().iloc[1][0]
    print(cov)
    a = cov/df["elements"].var()
    b = df["run_time"].mean() - df["elements"].mean()*a
    print("a: " + str(a) + ", b: " + str(b),'\n')
# Out:
# SelectionSort
# 818241810.4945055
# a: 37.82398644033641, b: -23640.409978861637
#
# InsertionSort
# 170107834.1142857
# a: 2.0792998919445274, b: -2484.722607912843
#
# MergeSort
# 3696310.114285714
# a: 0.045181559457538815, b: 5.2047788339767465
#
# CountingSort
# 1269726.914285714
# a: 0.015520408271729465, b: 4.9923709546987425
#
# NativeSort
# 9684698.009523809
# a: 0.11838015356299861, b: -8.061665573170103
#
# HeapSort
# 6052207.599999999
# a: 0.07397868930746093, b: -16.807961671676367
#
# QuickSort
# 4564100.295238095
# a: 0.05578892530215088, b: 5.395237949922944
